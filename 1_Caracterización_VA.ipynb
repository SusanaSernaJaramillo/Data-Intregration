# %% [markdown]
# <a href="https://colab.research.google.com/github/SusanaSernaJaramillo/Data-Intregration/blob/main/1_Caracterizaci%C3%B3n_VA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**GESTIÓN RIESGO OPERACIONAL -  EVERGREEN**
#
# En este espacio de trabajo se planea como caso de estudio el análisis de los riesgos asociados a las operaciones del negocio de la Naviera EVERGREEN.
#
# Esta naviera Taiwanesa opera en 240 puertos al rededor del mundo utilizando 150 buques Canal de Panáma.
#
# Los riesgos operacionales a los cuales estan expuesta la naviera estann relacionados con la logistica portuaria frente a la carga y descarga de contenedores. De esta manera, este riesgo operacional se describe a través de dos variables:
#
# - Frecuencia: Indica el número de contenedores que se queden en tierra por semana (Tiempo).
#
# - Severidad (KUSD):Indica el costo de solucionar cada evento de riesgo.
#
#
# Es importante mencionar que el producto entre la severidad y la frecuencia da como resultado la distribución agregada a las pérdidas (LDA - Loss Distribución Approach) y es precisamente que se hará la caracterización se hará la caracterización de esta distribución utilizando las medidas de tendencia de central (Mediana,Desviación) y las medidas de dispersión ( Coeficiente de asimetría, Kurtosis).

# %% [markdown]
# 0. Cargar librerias de trabajo

# %%
import numpy as np
import pandas as pd
import seaborn as sns # Esta es la liberia para el trabajo estadístico
import matplotlib.pyplot as plt

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 1. Se cargan los archivos de trabajo

# %%
nxl='/content/drive/MyDrive/Integración de datos/Bases de datos/1. RiesgoOperacional_EVERGREEEN.xlsx'
XDB=pd.read_excel(nxl,sheet_name=0)
XDB.head(10)
# Out:
#    Semana  Transacción Semanales  Valor Transado (MUSD)  Eventos (Semanales)  \
# 0       1                     44              27.145501                    4
# 1       2                    194              68.447342                   20
# 2       3                    217              20.111928                   22
# 3       4                    278              60.008094                   28
# 4       5                    286              63.007004                   31
# 5       6                    164              11.047362                   15
# 6       7                     47              11.794715                    5
# 7       8                    366             697.729253                   36
# 8       9                     39             117.075199                    4
# 9      10                    301              16.822844                   32
#
#    Severidad (KUSD)                                      Riesgo
# ...

# %%
#Procedemos con la distribución agregada de las pérdidas.

Freq=XDB.iloc[:,3]
Sev=XDB.iloc[:,4]
LDA=Freq*Sev


#Se procede con la contrucción de la dsitribución agregada de las peridas
plt.figure()
sns.histplot(LDA,bins=10,kde=True)
plt.grid()
plt.show()
